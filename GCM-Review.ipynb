# %%
from tabulate import tabulate
import intake
# Out:
# c:\Users\USER2\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import intake
import pandas as pd

url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(url)
df_info = col.df
grouped_info = df_info.groupby(['source_id', 'experiment_id'])['variable_id'].unique().reset_index()
result_df = pd.DataFrame(grouped_info)
result_df.columns = ['Model', 'Scenario','Variables']

# %%
result_df
# Out:
#             Model        Scenario  \
# 0      ACCESS-CM2         1pctCO2
# 1      ACCESS-CM2    abrupt-4xCO2
# 2      ACCESS-CM2        hist-GHG
# 3      ACCESS-CM2        hist-nat
# 4      ACCESS-CM2      historical
# ...           ...             ...
# 1170  UKESM1-0-LL  ssp370-lowNTCF
# 1171  UKESM1-0-LL       ssp370SST
# 1172  UKESM1-0-LL          ssp434
# 1173  UKESM1-0-LL     ssp534-over
# 1174  UKESM1-0-LL          ssp585
#
#                                               Variables
# 0     [ocontemppsmadvect, orog, areacella, tasmin, s...
# 1     [ts, ta, sfcWind, tasmax, tas, clt, clivi, cli...
# 2                                                 [tos]
# 3                              [tas, evspsbl, mrro, pr]
# 4     [tos, mlotst, agessc, huss, tas, vas, uas, ps,...
# ...                                                 ...
# 1170                                               [ps]
# 1171  [utendepfd, wtem, utendogw, vtem, utendnogw, u...
# 1172  [clt, siv, zostoga, sitemptop, siconca, tasmin...
# 1173  [hur, ps, hurs, hus, huss, rsds, pr, prc, rlds...
# 1174  [soga, masso, sosga, ps, rlds, rlus, tsl, prw,...
#
# [1175 rows x 3 columns]

# %%
var_id = result_df[result_df['Variables'].apply(lambda x: all(v in x for v in ['pr', 'tas', 'hur']))].reset_index()

# %%
var_id = var_id.drop("index", axis = 1)
var_id
# Out:
#            Model      Scenario  \
# 0     ACCESS-CM2       1pctCO2
# 1     ACCESS-CM2  abrupt-4xCO2
# 2     ACCESS-CM2    historical
# 3     ACCESS-CM2     piControl
# 4     ACCESS-CM2        ssp126
# ..           ...           ...
# 570  UKESM1-0-LL        ssp245
# 571  UKESM1-0-LL        ssp370
# 572  UKESM1-0-LL        ssp434
# 573  UKESM1-0-LL   ssp534-over
# 574  UKESM1-0-LL        ssp585
#
#                                              Variables
# 0    [ocontemppsmadvect, orog, areacella, tasmin, s...
# 1    [ts, ta, sfcWind, tasmax, tas, clt, clivi, cli...
# 2    [tos, mlotst, agessc, huss, tas, vas, uas, ps,...
# 3    [so, fsitherm, mrsos, mrso, mrro, wfo, wmo, rs...
# 4    [snw, zfull, sftlf, sftgif, orog, areacella, v...
# ..                                                 ...
# 570  [vas, wap, zg, so, prra, thetaoga, siv, sitemp...
# 571  [thetao, sosga, sos, soga, prsn, prra, mlotst,...
# 572  [clt, siv, zostoga, sitemptop, siconca, tasmin...
# 573  [hur, ps, hurs, hus, huss, rsds, pr, prc, rlds...
# 574  [soga, masso, sosga, ps, rlds, rlus, tsl, prw,...
#
# [575 rows x 3 columns]

# %%
var_id = var_id.pivot(index='Model', columns='Scenario', values='Variables').reset_index()
var_id.head()
# Out:
# Scenario           Model                                            1pctCO2  \
# 0             ACCESS-CM2  [ocontemppsmadvect, orog, areacella, tasmin, s...
# 1          ACCESS-ESM1-5  [evspsblsoi, po4, pbo, o2, no3, masscello, dep...
# 2          AWI-CM-1-1-MR  [sivol, tasmax, snw, sfcWindmax, sivols, sivol...
# 3         AWI-ESM-1-1-LR  [mrsol, cLitter, cVeg, gpp, lai, mrro, tas, tr...
# 4            BCC-CSM2-MR  [mrros, gpp, mrsol, snw, cLitter, cVeg, evspsb...
#
# Scenario                                        1pctCO2-bgc  \
# 0                                                       NaN
# 1         [fgco2nat, fgo2, fsitherm, masscello, mlotst, ...
# 2                                                       NaN
# 3                                                       NaN
# 4         [mrsol, cLitter, cVeg, evspsblsoi, evspsblveg,...
#
# Scenario                                        1pctCO2-rad  \
# 0                                                       NaN
# 1         [mrsos, mrsol, hurs, hus, ps, psl, tas, tasmax...
# 2                                                       NaN
# 3                                                       NaN
# 4         [lai, mrro, mrros, mrso, mrsos, tran, gpp, evs...
#
# Scenario                                       abrupt-4xCO2  \
# 0         [ts, ta, sfcWind, tasmax, tas, clt, clivi, cli...
# 1         [sfcWind, rtmt, rsutcs, rsut, rsus, rsdt, huss...
# 2         [tasmax, sitimefrac, tasmin, sivols, va, wap, ...
# 3                                                       NaN
# 4         [snw, mrro, mrsos, mrso, simass, sisnthick, si...
#
# Scenario                                               amip amip-4xCO2  \
# 0                                                       NaN        NaN
# 1         [sftlf, zfull, sftgif, orog, areacella, hur, m...        NaN
# 2                                                       NaN        NaN
# 3                                                       NaN        NaN
# 4         [gpp, mrros, tran, mrsos, mrso, lai, mrro, evs...        NaN
#
# Scenario amip-hist amip-lwoff amip-p4K  ... ssp370-lowNTCF ssp370SST  \
# 0              NaN        NaN      NaN  ...            NaN       NaN
# 1              NaN        NaN      NaN  ...            NaN       NaN
# 2              NaN        NaN      NaN  ...            NaN       NaN
# 3              NaN        NaN      NaN  ...            NaN       NaN
# 4              NaN        NaN      NaN  ...            NaN       NaN
#
# Scenario ssp370SST-lowCH4 ssp370SST-lowNTCF ssp370SST-ssp126Lu ssp370pdSST  \
# 0                     NaN               NaN                NaN         NaN
# 1                     NaN               NaN                NaN         NaN
# 2                     NaN               NaN                NaN         NaN
# 3                     NaN               NaN                NaN         NaN
# 4                     NaN               NaN                NaN         NaN
#
# Scenario ssp434 ssp460 ssp534-over  \
# 0           NaN    NaN         NaN
# 1           NaN    NaN         NaN
# 2           NaN    NaN         NaN
# 3           NaN    NaN         NaN
# 4           NaN    NaN         NaN
#
# Scenario                                             ssp585
# 0         [rlutcs, shrubFrac, treeFrac, vegFrac, grassFr...
# 1         [msftmrho, ps, prc, psl, tauu, pr, zooc, rlut,...
# 2         [sisnconc, tauuo, thetaoga, tos, uo, vo, volo,...
# 3                                                       NaN
# 4         [cLeaf, snw, snc, cLitterAbove, cLitterBelow, ...
#
# [5 rows x 68 columns]

# %%
exp_id = var_id[['Model','ssp119','ssp126', 'ssp245', 'ssp370', 'ssp434', 'ssp460','ssp585']]

# %%
exp_id.head()
# Out:
# Scenario           Model ssp119  \
# 0             ACCESS-CM2    NaN
# 1          ACCESS-ESM1-5    NaN
# 2          AWI-CM-1-1-MR    NaN
# 3         AWI-ESM-1-1-LR    NaN
# 4            BCC-CSM2-MR    NaN
#
# Scenario                                             ssp126  \
# 0         [snw, zfull, sftlf, sftgif, orog, areacella, v...
# 1         [msftmrho, npp, vas, tas, uas, ts, sfcWind, ar...
# 2         [sispeed, sisnthick, sisnmass, sisnconc, siext...
# 3                                                       NaN
# 4         [snw, mrsos, mrso, mrro, uas, va, vas, o3, wap...
#
# Scenario                                             ssp245  \
# 0         [tos, areacello, basin, deptho, cropFrac, tas,...
# 1                                                       NaN
# 2         [vo, uo, tos, thetaoga, thetao, tauvo, tauuo, ...
# 3                                                       NaN
# 4         [mrso, mrsos, snw, mrro, ra, tsl, rh, npp, prv...
#
# Scenario                                             ssp370 ssp434 ssp460  \
# 0         [zostoga, uo, zos, wmo, vo, tasmax, tasmin, ua...    NaN    NaN
# 1         [po4, no3, so, talk, zooc, siconc, mrro, gpp, ...    NaN    NaN
# 2         [sithick, sitimefrac, siu, siv, sivol, sispeed...    NaN    NaN
# 3                                                       NaN    NaN    NaN
# 4         [snw, cLitter, mrsol, cSoil, cVeg, evspsblveg,...    NaN    NaN
#
# Scenario                                             ssp585
# 0         [rlutcs, shrubFrac, treeFrac, vegFrac, grassFr...
# 1         [msftmrho, ps, prc, psl, tauu, pr, zooc, rlut,...
# 2         [sisnconc, tauuo, thetaoga, tos, uo, vo, volo,...
# 3                                                       NaN
# 4         [cLeaf, snw, snc, cLitterAbove, cLitterBelow, ...

# %%
exp_id = exp_id.dropna(subset=exp_id.columns[1:], how='all')

# %%
import numpy as np

df = exp_id.copy()
df = df.apply(lambda col: col.apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x))

# %%
def select_specific_words(word_list):
    if isinstance(word_list, list):
        return [word for word in word_list if word in ['tas', 'pr', 'hur']]
    else:
        return []
df.iloc[:, 1:] = df.iloc[:, 1:].applymap(select_specific_words)
# Out:
# C:\Users\USER2\AppData\Local\Temp\ipykernel_36540\2439976057.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.iloc[:, 1:] = df.iloc[:, 1:].applymap(select_specific_words)

# %%
df = df.applymap(lambda x: " " if isinstance(x, list) and not x else x)
# Out:
# C:\Users\USER2\AppData\Local\Temp\ipykernel_36540\4154077279.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: " " if isinstance(x, list) and not x else x)

# %%
df
# Out:
# Scenario              Model          ssp119          ssp126          ssp245  \
# 0                ACCESS-CM2                  [tas, hur, pr]  [tas, hur, pr]
# 1             ACCESS-ESM1-5                  [tas, pr, hur]
# 2             AWI-CM-1-1-MR                  [pr, hur, tas]  [pr, hur, tas]
# 4               BCC-CSM2-MR                  [pr, tas, hur]  [pr, tas, hur]
# 5                  BCC-ESM1
# 6               CAMS-CSM1-0  [pr, hur, tas]  [hur, pr, tas]  [tas, hur, pr]
# 7                CAS-ESM2-0                  [pr, hur, tas]  [tas, pr, hur]
# 8                     CESM2                  [hur, pr, tas]  [tas, hur, pr]
# 10              CESM2-WACCM                  [hur, pr, tas]  [hur, tas, pr]
# 12                    CIESM                  [tas, hur, pr]  [tas, pr, hur]
# 14             CMCC-CM2-SR5                  [pr, tas, hur]  [tas, pr, hur]
# 15                CMCC-ESM2                  [tas, pr, hur]  [pr, tas, hur]
# 16               CNRM-CM6-1                  [hur, pr, tas]  [tas, pr, hur]
# 17            CNRM-CM6-1-HR                  [tas, pr, hur]  [hur, tas, pr]
# 18              CNRM-ESM2-1  [tas, hur, pr]  [pr, tas, hur]  [pr, tas, hur]
# 19                  CanESM5  [tas, hur, pr]  [tas, pr, hur]  [pr, hur, tas]
# 20            CanESM5-CanOE                  [hur, pr, tas]  [tas, hur, pr]
# 22                 E3SM-1-1
# 24                EC-Earth3  [tas, pr, hur]  [pr, tas, hur]  [hur, tas, pr]
# 25        EC-Earth3-AerChem
# 26             EC-Earth3-CC                                  [pr, hur, tas]
# 28            EC-Earth3-Veg  [pr, hur, tas]  [tas, pr, hur]  [tas, pr, hur]
# 29         EC-Earth3-Veg-LR  [tas, pr, hur]  [hur, pr, tas]  [pr, tas, hur]
# 30              FGOALS-f3-L                  [tas, pr, hur]  [pr, hur, tas]
# 31                FGOALS-g3  [tas, hur, pr]  [tas, hur, pr]  [tas, pr, hur]
# 32              FIO-ESM-2-0                  [pr, tas, hur]  [pr, tas, hur]
# 34                 GFDL-CM4                                  [tas, hur, pr]
# 36                GFDL-ESM4  [tas, pr, hur]  [pr, tas, hur]  [tas, pr, hur]
# 37              GISS-E2-1-G  [pr, tas, hur]  [tas, pr, hur]  [pr, tas, hur]
# 39              GISS-E2-1-H
# 42          HadGEM3-GC31-LL                  [pr, tas, hur]  [hur, pr, tas]
# 43          HadGEM3-GC31-MM                  [tas, pr, hur]
# 45                 IITM-ESM                  [tas, hur, pr]  [tas, pr, hur]
# 46                INM-CM4-8                  [tas, pr, hur]  [pr, tas, hur]
# 47                INM-CM5-0                  [pr, hur, tas]  [hur, pr, tas]
# 48             IPSL-CM6A-LR  [pr, hur, tas]  [pr, tas, hur]  [pr, tas, hur]
# 50               KACE-1-0-G                  [pr, hur, tas]  [pr, tas, hur]
# 51                KIOST-ESM                  [tas, pr, hur]  [tas, pr, hur]
# 52               MCM-UA-1-0                  [hur, pr, tas]  [hur, tas, pr]
# 54               MIROC-ES2L  [tas, pr, hur]  [tas, pr, hur]  [tas, hur, pr]
# 55                   MIROC6  [pr, hur, tas]  [pr, hur, tas]  [hur, pr, tas]
# 56          MPI-ESM-1-2-HAM
# 57            MPI-ESM1-2-HR                  [tas, hur, pr]  [pr, hur, tas]
# 58            MPI-ESM1-2-LR                  [tas, pr, hur]  [hur, pr, tas]
# 59               MRI-ESM2-0  [pr, tas, hur]  [tas, hur, pr]  [pr, tas, hur]
# 60                    NESM3                  [tas, hur, pr]  [tas, pr, hur]
# 62               NorESM2-LM                  [hur, tas, pr]  [tas, pr, hur]
# 63               NorESM2-MM                  [pr, tas, hur]  [pr, hur, tas]
# 65                  TaiESM1                  [hur, pr, tas]  [pr, hur, tas]
# 66              UKESM1-0-LL  [pr, tas, hur]  [tas, hur, pr]  [tas, pr, hur]
#
# Scenario          ssp370          ssp434          ssp460          ssp585
# 0         [tas, pr, hur]                                  [hur, tas, pr]
# 1         [hur, pr, tas]                                  [pr, tas, hur]
# 2         [hur, pr, tas]                                  [pr, hur, tas]
# 4         [hur, pr, tas]                                  [pr, hur, tas]
# 5         [tas, pr, hur]
# 6         [tas, hur, pr]                                  [hur, tas, pr]
# 7         [tas, hur, pr]                                  [hur, pr, tas]
# 8         [tas, hur, pr]                                  [hur, pr, tas]
# 10        [tas, hur, pr]                                  [hur, tas, pr]
# 12                                                        [tas, hur, pr]
# 14        [tas, hur, pr]                                  [pr, hur, tas]
# 15        [pr, hur, tas]                                  [pr, hur, tas]
# 16        [tas, pr, hur]                                  [tas, pr, hur]
# 17        [tas, hur, pr]                                  [tas, hur, pr]
# 18        [hur, pr, tas]  [pr, tas, hur]  [pr, tas, hur]  [tas, pr, hur]
# 19        [hur, tas, pr]  [tas, pr, hur]  [tas, pr, hur]  [pr, tas, hur]
# 20        [tas, hur, pr]                                  [pr, hur, tas]
# 22                                                        [tas, pr, hur]
# 24        [pr, tas, hur]                                  [tas, pr, hur]
# 25        [pr, hur, tas]
# 26                                                        [tas, pr, hur]
# 28        [pr, tas, hur]                                  [tas, pr, hur]
# 29        [hur, pr, tas]                                  [pr, tas, hur]
# 30        [hur, pr, tas]                                  [pr, hur, tas]
# 31        [pr, tas, hur]  [tas, pr, hur]  [hur, pr, tas]  [hur, pr, tas]
# 32                                                        [pr, tas, hur]
# 34                                                        [tas, hur, pr]
# 36        [tas, pr, hur]                                  [pr, tas, hur]
# 37        [hur, pr, tas]  [tas, pr, hur]  [hur, tas, pr]  [pr, tas, hur]
# 39        [tas, hur, pr]                                  [hur, pr, tas]
# 42                                                        [tas, hur, pr]
# 43                                                        [pr, tas, hur]
# 45        [tas, hur, pr]                                  [tas, pr, hur]
# 46        [pr, tas, hur]                                  [pr, tas, hur]
# 47        [pr, tas, hur]                                  [hur, pr, tas]
# 48        [tas, hur, pr]  [pr, hur, tas]  [pr, hur, tas]  [pr, tas, hur]
# 50        [pr, tas, hur]                                  [tas, pr, hur]
# 51                                                        [pr, tas, hur]
# 52        [pr, tas, hur]                                  [tas, hur, pr]
# 54        [tas, hur, pr]                                  [pr, hur, tas]
# 55        [pr, hur, tas]  [pr, hur, tas]  [hur, tas, pr]  [hur, pr, tas]
# 56        [hur, pr, tas]
# 57        [tas, hur, pr]                                  [tas, pr, hur]
# 58        [pr, tas, hur]                                  [tas, pr, hur]
# 59        [tas, pr, hur]  [pr, tas, hur]  [tas, pr, hur]  [pr, tas, hur]
# 60                                                        [pr, hur, tas]
# 62        [pr, tas, hur]                                  [hur, tas, pr]
# 63        [hur, tas, pr]                                  [tas, pr, hur]
# 65        [tas, hur, pr]                                  [tas, hur, pr]
# 66        [pr, tas, hur]  [hur, pr, tas]                  [tas, pr, hur]
