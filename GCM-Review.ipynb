# %%
from tabulate import tabulate
import intake
# Out:
# c:\Users\USER2\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import intake
import pandas as pd

url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(url)
df_info = col.df
grouped_info = df_info.groupby(['source_id', 'experiment_id'])['variable_id'].unique().reset_index()
result_df = pd.DataFrame(grouped_info)
result_df.columns = ['Model', 'Scenario','Variables']

# %%
result_df
# Out:
#             Model        Scenario  \
# 0      ACCESS-CM2         1pctCO2
# 1      ACCESS-CM2    abrupt-4xCO2
# 2      ACCESS-CM2        hist-GHG
# 3      ACCESS-CM2        hist-nat
# 4      ACCESS-CM2      historical
# ...           ...             ...
# 1170  UKESM1-0-LL  ssp370-lowNTCF
# 1171  UKESM1-0-LL       ssp370SST
# 1172  UKESM1-0-LL          ssp434
# 1173  UKESM1-0-LL     ssp534-over
# 1174  UKESM1-0-LL          ssp585
#
#                                               Variables
# 0     [ocontemppsmadvect, orog, areacella, tasmin, s...
# 1     [ts, ta, sfcWind, tasmax, tas, clt, clivi, cli...
# 2                                                 [tos]
# 3                              [tas, evspsbl, mrro, pr]
# 4     [tos, mlotst, agessc, huss, tas, vas, uas, ps,...
# ...                                                 ...
# 1170                                               [ps]
# 1171  [utendepfd, wtem, utendogw, vtem, utendnogw, u...
# 1172  [clt, siv, zostoga, sitemptop, siconca, tasmin...
# 1173  [hur, ps, hurs, hus, huss, rsds, pr, prc, rlds...
# 1174  [soga, masso, sosga, ps, rlds, rlus, tsl, prw,...
#
# [1175 rows x 3 columns]

# %%
var_id = result_df[result_df['Variables'].apply(lambda x: all(v in x for v in ['pr', 'tasmax', 'tasmin', 'hur']))].reset_index()

# %%
var_id = var_id.drop("index", axis = 1)
var_id
# Out:
#            Model      Scenario  \
# 0     ACCESS-CM2       1pctCO2
# 1     ACCESS-CM2  abrupt-4xCO2
# 2     ACCESS-CM2    historical
# 3     ACCESS-CM2     piControl
# 4     ACCESS-CM2        ssp126
# ..           ...           ...
# 422  UKESM1-0-LL        ssp245
# 423  UKESM1-0-LL        ssp370
# 424  UKESM1-0-LL        ssp434
# 425  UKESM1-0-LL   ssp534-over
# 426  UKESM1-0-LL        ssp585
#
#                                              Variables
# 0    [ocontemppsmadvect, orog, areacella, tasmin, s...
# 1    [ts, ta, sfcWind, tasmax, tas, clt, clivi, cli...
# 2    [tos, mlotst, agessc, huss, tas, vas, uas, ps,...
# 3    [so, fsitherm, mrsos, mrso, mrro, wfo, wmo, rs...
# 4    [snw, zfull, sftlf, sftgif, orog, areacella, v...
# ..                                                 ...
# 422  [vas, wap, zg, so, prra, thetaoga, siv, sitemp...
# 423  [thetao, sosga, sos, soga, prsn, prra, mlotst,...
# 424  [clt, siv, zostoga, sitemptop, siconca, tasmin...
# 425  [hur, ps, hurs, hus, huss, rsds, pr, prc, rlds...
# 426  [soga, masso, sosga, ps, rlds, rlus, tsl, prw,...
#
# [427 rows x 3 columns]

# %%
var_id = var_id.pivot(index='Model', columns='Scenario', values='Variables').reset_index()
var_id.head()
# Out:
# Scenario           Model                                            1pctCO2  \
# 0             ACCESS-CM2  [ocontemppsmadvect, orog, areacella, tasmin, s...
# 1          ACCESS-ESM1-5  [evspsblsoi, po4, pbo, o2, no3, masscello, dep...
# 2          AWI-CM-1-1-MR  [sivol, tasmax, snw, sfcWindmax, sivols, sivol...
# 3         AWI-ESM-1-1-LR                                                NaN
# 4            BCC-CSM2-MR  [mrros, gpp, mrsol, snw, cLitter, cVeg, evspsb...
#
# Scenario                                        1pctCO2-bgc  \
# 0                                                       NaN
# 1         [fgco2nat, fgo2, fsitherm, masscello, mlotst, ...
# 2                                                       NaN
# 3                                                       NaN
# 4         [mrsol, cLitter, cVeg, evspsblsoi, evspsblveg,...
#
# Scenario                                        1pctCO2-rad  \
# 0                                                       NaN
# 1         [mrsos, mrsol, hurs, hus, ps, psl, tas, tasmax...
# 2                                                       NaN
# 3                                                       NaN
# 4         [lai, mrro, mrros, mrso, mrsos, tran, gpp, evs...
#
# Scenario                                       abrupt-4xCO2  \
# 0         [ts, ta, sfcWind, tasmax, tas, clt, clivi, cli...
# 1         [sfcWind, rtmt, rsutcs, rsut, rsus, rsdt, huss...
# 2         [tasmax, sitimefrac, tasmin, sivols, va, wap, ...
# 3                                                       NaN
# 4         [snw, mrro, mrsos, mrso, simass, sisnthick, si...
#
# Scenario                                               amip amip-4xCO2  \
# 0                                                       NaN        NaN
# 1         [sftlf, zfull, sftgif, orog, areacella, hur, m...        NaN
# 2                                                       NaN        NaN
# 3                                                       NaN        NaN
# 4                                                       NaN        NaN
#
# Scenario amip-hist amip-lwoff amip-p4K  ... ssp370-lowNTCF ssp370SST  \
# 0              NaN        NaN      NaN  ...            NaN       NaN
# 1              NaN        NaN      NaN  ...            NaN       NaN
# 2              NaN        NaN      NaN  ...            NaN       NaN
# 3              NaN        NaN      NaN  ...            NaN       NaN
# 4              NaN        NaN      NaN  ...            NaN       NaN
#
# Scenario ssp370SST-lowCH4 ssp370SST-lowNTCF ssp370SST-ssp126Lu ssp370pdSST  \
# 0                     NaN               NaN                NaN         NaN
# 1                     NaN               NaN                NaN         NaN
# 2                     NaN               NaN                NaN         NaN
# 3                     NaN               NaN                NaN         NaN
# 4                     NaN               NaN                NaN         NaN
#
# Scenario ssp434 ssp460 ssp534-over  \
# 0           NaN    NaN         NaN
# 1           NaN    NaN         NaN
# 2           NaN    NaN         NaN
# 3           NaN    NaN         NaN
# 4           NaN    NaN         NaN
#
# Scenario                                             ssp585
# 0         [rlutcs, shrubFrac, treeFrac, vegFrac, grassFr...
# 1         [msftmrho, ps, prc, psl, tauu, pr, zooc, rlut,...
# 2         [sisnconc, tauuo, thetaoga, tos, uo, vo, volo,...
# 3                                                       NaN
# 4         [cLeaf, snw, snc, cLitterAbove, cLitterBelow, ...
#
# [5 rows x 61 columns]

# %%
exp_id = var_id[['Model','ssp119','ssp126', 'ssp245', 'ssp370', 'ssp434', 'ssp460','ssp585']]

# %%
exp_id.head()
# Out:
# Scenario           Model ssp119  \
# 0             ACCESS-CM2    NaN
# 1          ACCESS-ESM1-5    NaN
# 2          AWI-CM-1-1-MR    NaN
# 3         AWI-ESM-1-1-LR    NaN
# 4            BCC-CSM2-MR    NaN
#
# Scenario                                             ssp126  \
# 0         [snw, zfull, sftlf, sftgif, orog, areacella, v...
# 1                                                       NaN
# 2         [sispeed, sisnthick, sisnmass, sisnconc, siext...
# 3                                                       NaN
# 4         [snw, mrsos, mrso, mrro, uas, va, vas, o3, wap...
#
# Scenario                                             ssp245  \
# 0         [tos, areacello, basin, deptho, cropFrac, tas,...
# 1                                                       NaN
# 2         [vo, uo, tos, thetaoga, thetao, tauvo, tauuo, ...
# 3                                                       NaN
# 4         [mrso, mrsos, snw, mrro, ra, tsl, rh, npp, prv...
#
# Scenario                                             ssp370 ssp434 ssp460  \
# 0         [zostoga, uo, zos, wmo, vo, tasmax, tasmin, ua...    NaN    NaN
# 1                                                       NaN    NaN    NaN
# 2         [sithick, sitimefrac, siu, siv, sivol, sispeed...    NaN    NaN
# 3                                                       NaN    NaN    NaN
# 4         [snw, cLitter, mrsol, cSoil, cVeg, evspsblveg,...    NaN    NaN
#
# Scenario                                             ssp585
# 0         [rlutcs, shrubFrac, treeFrac, vegFrac, grassFr...
# 1         [msftmrho, ps, prc, psl, tauu, pr, zooc, rlut,...
# 2         [sisnconc, tauuo, thetaoga, tos, uo, vo, volo,...
# 3                                                       NaN
# 4         [cLeaf, snw, snc, cLitterAbove, cLitterBelow, ...

# %%
exp_id = exp_id.dropna(subset=exp_id.columns[1:], how='all')

# %%
import numpy as np

df = exp_id.copy()
df = df.apply(lambda col: col.apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x))

# %%
def select_specific_words(word_list):
    if isinstance(word_list, list):
        return [word for word in word_list if word in ['tasmax', 'tasmin', 'pr', 'hur']]
    else:
        return []
df.iloc[:, 1:] = df.iloc[:, 1:].applymap(select_specific_words)
# Out:
# C:\Users\USER2\AppData\Local\Temp\ipykernel_4868\2698735631.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.iloc[:, 1:] = df.iloc[:, 1:].applymap(select_specific_words)

# %%
df = df.applymap(lambda x: " " if isinstance(x, list) and not x else x)
# Out:
# C:\Users\USER2\AppData\Local\Temp\ipykernel_4868\4154077279.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: " " if isinstance(x, list) and not x else x)

# %%
df
# Out:
# Scenario              Model                     ssp119  \
# 0                ACCESS-CM2
# 1             ACCESS-ESM1-5
# 2             AWI-CM-1-1-MR
# 4               BCC-CSM2-MR
# 5                  BCC-ESM1
# 6                     CESM2
# 7               CESM2-WACCM
# 8                     CIESM
# 9                 CMCC-ESM2
# 10               CNRM-CM6-1
# 11            CNRM-CM6-1-HR
# 12              CNRM-ESM2-1  [tasmin, tasmax, hur, pr]
# 13                  CanESM5  [tasmin, tasmax, hur, pr]
# 14            CanESM5-CanOE
# 15                EC-Earth3  [tasmax, pr, tasmin, hur]
# 16        EC-Earth3-AerChem
# 17             EC-Earth3-CC
# 19            EC-Earth3-Veg  [pr, hur, tasmax, tasmin]
# 20         EC-Earth3-Veg-LR  [tasmin, tasmax, pr, hur]
# 22                FGOALS-g3  [hur, tasmin, tasmax, pr]
# 23              FIO-ESM-2-0
# 25                 GFDL-CM4
# 27                GFDL-ESM4  [pr, tasmin, tasmax, hur]
# 28              GISS-E2-1-G  [pr, tasmax, hur, tasmin]
# 32          HadGEM3-GC31-LL
# 33          HadGEM3-GC31-MM
# 34                 IITM-ESM
# 35                INM-CM4-8
# 36                INM-CM5-0
# 37             IPSL-CM6A-LR  [pr, hur, tasmin, tasmax]
# 38               KACE-1-0-G
# 39                KIOST-ESM
# 40               MIROC-ES2L  [tasmin, tasmax, pr, hur]
# 41                   MIROC6  [pr, hur, tasmax, tasmin]
# 42          MPI-ESM-1-2-HAM
# 43            MPI-ESM1-2-HR
# 44            MPI-ESM1-2-LR
# 45               MRI-ESM2-0  [pr, tasmax, tasmin, hur]
# 46                    NESM3
# 47               NorESM2-LM
# 48               NorESM2-MM
# 50                  TaiESM1
# 51              UKESM1-0-LL  [tasmin, tasmax, pr, hur]
#
# Scenario                     ssp126                     ssp245  \
# 0         [tasmax, hur, tasmin, pr]  [tasmax, hur, tasmin, pr]
# 1
# 2         [pr, hur, tasmin, tasmax]  [tasmin, pr, hur, tasmax]
# 4         [pr, tasmax, hur, tasmin]  [pr, tasmin, tasmax, hur]
# 5
# 6         [hur, pr, tasmin, tasmax]  [tasmax, tasmin, hur, pr]
# 7         [hur, pr, tasmax, tasmin]  [hur, pr, tasmin, tasmax]
# 8         [tasmin, tasmax, hur, pr]  [tasmin, tasmax, pr, hur]
# 9         [tasmin, tasmax, pr, hur]  [pr, tasmin, tasmax, hur]
# 10        [tasmin, tasmax, hur, pr]  [tasmin, tasmax, pr, hur]
# 11        [tasmax, tasmin, pr, hur]  [hur, pr, tasmax, tasmin]
# 12        [pr, tasmin, tasmax, hur]  [tasmax, pr, tasmin, hur]
# 13        [tasmin, tasmax, pr, hur]  [pr, hur, tasmin, tasmax]
# 14        [tasmin, hur, pr, tasmax]  [tasmin, tasmax, hur, pr]
# 15        [pr, tasmax, tasmin, hur]  [hur, tasmin, tasmax, pr]
# 16
# 17                                   [pr, hur, tasmax, tasmin]
# 19        [tasmax, pr, tasmin, hur]  [tasmin, tasmax, pr, hur]
# 20        [hur, pr, tasmax, tasmin]  [pr, tasmax, tasmin, hur]
# 22        [tasmin, tasmax, hur, pr]  [tasmin, tasmax, pr, hur]
# 23        [pr, hur, tasmax, tasmin]  [pr, hur, tasmin, tasmax]
# 25                                   [tasmin, tasmax, hur, pr]
# 27        [pr, tasmin, tasmax, hur]  [tasmax, tasmin, pr, hur]
# 28        [tasmax, tasmin, pr, hur]  [pr, tasmin, hur, tasmax]
# 32        [pr, tasmin, hur, tasmax]  [hur, tasmax, tasmin, pr]
# 33        [tasmin, tasmax, pr, hur]
# 34        [tasmin, hur, pr, tasmax]
# 35        [tasmax, tasmin, pr, hur]  [pr, tasmax, tasmin, hur]
# 36        [pr, hur, tasmax, tasmin]  [hur, pr, tasmax, tasmin]
# 37        [pr, tasmax, tasmin, hur]  [tasmax, pr, hur, tasmin]
# 38        [pr, hur, tasmin, tasmax]  [pr, hur, tasmax, tasmin]
# 39        [tasmin, tasmax, pr, hur]  [tasmin, tasmax, pr, hur]
# 40        [tasmin, tasmax, pr, hur]  [tasmin, hur, tasmax, pr]
# 41        [pr, hur, tasmax, tasmin]  [hur, pr, tasmax, tasmin]
# 42
# 43        [tasmin, tasmax, hur, pr]  [pr, hur, tasmax, tasmin]
# 44        [tasmin, pr, tasmax, hur]  [hur, tasmax, tasmin, pr]
# 45        [tasmax, hur, tasmin, pr]  [pr, tasmin, tasmax, hur]
# 46        [tasmax, tasmin, hur, pr]  [tasmax, tasmin, pr, hur]
# 47                                   [tasmax, tasmin, pr, hur]
# 48        [tasmin, pr, tasmax, hur]  [pr, hur, tasmax, tasmin]
# 50                                   [pr, hur, tasmax, tasmin]
# 51        [hur, pr, tasmax, tasmin]  [pr, hur, tasmin, tasmax]
#
# Scenario                     ssp370                     ssp434  \
# 0         [tasmax, tasmin, pr, hur]
# 1
# 2         [hur, pr, tasmin, tasmax]
# 4         [hur, tasmax, pr, tasmin]
# 5         [tasmax, tasmin, pr, hur]
# 6         [tasmin, tasmax, hur, pr]
# 7
# 8
# 9         [tasmax, pr, tasmin, hur]
# 10        [pr, hur, tasmax, tasmin]
# 11        [tasmax, tasmin, hur, pr]
# 12        [tasmax, tasmin, hur, pr]  [pr, tasmin, tasmax, hur]
# 13        [hur, tasmax, tasmin, pr]  [tasmax, pr, hur, tasmin]
# 14        [tasmin, tasmax, hur, pr]
# 15        [pr, tasmax, tasmin, hur]
# 16        [pr, hur, tasmax, tasmin]
# 17
# 19        [tasmax, pr, tasmin, hur]
# 20        [tasmin, hur, pr, tasmax]
# 22        [pr, tasmax, tasmin, hur]  [tasmax, tasmin, pr, hur]
# 23
# 25
# 27        [pr, tasmax, tasmin, hur]
# 28        [hur, pr, tasmax, tasmin]  [pr, tasmax, tasmin, hur]
# 32
# 33
# 34
# 35        [pr, tasmax, tasmin, hur]
# 36        [pr, tasmin, tasmax, hur]
# 37        [tasmax, tasmin, hur, pr]  [tasmin, pr, hur, tasmax]
# 38        [pr, hur, tasmin, tasmax]
# 39
# 40        [tasmin, tasmax, hur, pr]
# 41        [pr, hur, tasmax, tasmin]  [pr, hur, tasmin, tasmax]
# 42        [hur, pr, tasmax, tasmin]
# 43        [hur, pr, tasmin, tasmax]
# 44        [pr, tasmin, hur, tasmax]
# 45        [tasmin, tasmax, pr, hur]  [pr, tasmin, tasmax, hur]
# 46
# 47        [pr, tasmin, tasmax, hur]
# 48        [hur, pr, tasmax, tasmin]
# 50
# 51        [pr, hur, tasmin, tasmax]  [tasmin, tasmax, hur, pr]
#
# Scenario                     ssp460                     ssp585
# 0                                    [hur, tasmax, tasmin, pr]
# 1                                    [pr, tasmin, tasmax, hur]
# 2                                    [pr, hur, tasmin, tasmax]
# 4                                    [pr, hur, tasmin, tasmax]
# 5
# 6                                    [hur, pr, tasmin, tasmax]
# 7                                    [hur, pr, tasmin, tasmax]
# 8                                    [tasmax, tasmin, hur, pr]
# 9                                    [pr, hur, tasmax, tasmin]
# 10                                   [pr, tasmax, hur, tasmin]
# 11                                   [tasmin, tasmax, hur, pr]
# 12        [tasmax, tasmin, pr, hur]  [tasmin, tasmax, pr, hur]
# 13        [tasmin, tasmax, pr, hur]  [pr, tasmax, tasmin, hur]
# 14                                   [pr, hur, tasmax, tasmin]
# 15                                   [tasmin, tasmax, pr, hur]
# 16
# 17                                   [tasmax, tasmin, pr, hur]
# 19                                   [pr, hur, tasmin, tasmax]
# 20                                   [pr, tasmin, tasmax, hur]
# 22        [hur, pr, tasmax, tasmin]  [hur, pr, tasmin, tasmax]
# 23                                   [pr, hur, tasmax, tasmin]
# 25                                   [tasmax, tasmin, hur, pr]
# 27                                   [pr, tasmax, tasmin, hur]
# 28        [hur, pr, tasmax, tasmin]  [pr, hur, tasmin, tasmax]
# 32                                   [tasmin, tasmax, hur, pr]
# 33                                   [tasmin, pr, tasmax, hur]
# 34
# 35                                   [pr, tasmin, tasmax, hur]
# 36                                   [hur, pr, tasmin, tasmax]
# 37        [pr, hur, tasmax, tasmin]  [pr, tasmin, tasmax, hur]
# 38                                   [pr, hur, tasmax, tasmin]
# 39                                   [pr, tasmax, tasmin, hur]
# 40                                   [pr, hur, tasmax, tasmin]
# 41        [hur, tasmax, tasmin, pr]  [hur, pr, tasmin, tasmax]
# 42
# 43                                   [tasmin, tasmax, pr, hur]
# 44                                   [tasmin, tasmax, pr, hur]
# 45        [tasmin, pr, tasmax, hur]  [pr, tasmin, tasmax, hur]
# 46                                   [pr, hur, tasmax, tasmin]
# 47                                   [hur, pr, tasmax, tasmin]
# 48                                   [tasmin, tasmax, pr, hur]
# 50                                   [hur, pr, tasmax, tasmin]
# 51                                   [pr, hur, tasmin, tasmax]
